# %%
import pandas as pd

# %%
pd.read_csv('cleaned_solar_energy_production_calgary.csv')
# Out:
#             id               address     kWh installationDate  year  month  \
# 0       164440  2000 SOUTHLAND DR SW  27.805       2015-09-01  2015      9
# 1       164440  2000 SOUTHLAND DR SW  30.559       2015-09-01  2015      9
# 2       164440  2000 SOUTHLAND DR SW  23.613       2015-09-01  2015      9
# 3       164440  2000 SOUTHLAND DR SW  15.257       2015-09-01  2015      9
# 4       164440  2000 SOUTHLAND DR SW   7.896       2015-09-01  2015      9
# ...        ...                   ...     ...              ...   ...    ...
# 264374  594148  220 ST GEORGES DR NE   9.092       2017-11-27  2018      1
# 264375  594148  220 ST GEORGES DR NE   9.979       2017-11-27  2018      1
# 264376  594148  220 ST GEORGES DR NE   8.423       2017-11-27  2018      1
# 264377  594148  220 ST GEORGES DR NE   4.346       2017-11-27  2018      1
# 264378  594148  220 ST GEORGES DR NE   0.335       2017-11-27  2018      1
#
#         day  time_hour  time_min  name_CFD Firehall #7  \
# ...
